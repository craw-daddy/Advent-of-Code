# %%
from DijkstraGrid import DijkstraGrid

import copy

# %%
with open('data/12-16.input') as f:
    data = f.read().strip()

# %%
data = '''###############
#.......#....E#
#.#.###.#.###.#
#.....#.#...#.#
#.###.#####.#.#
#.#.#.......#.#
#.#.#####.###.#
#...........#.#
###.#.#####.#.#
#...#.....#.#.#
#.#.#.###.#.#.#
#.....#...#.#.#
#.###.#.#.#.#.#
#S..#.....#...#
###############'''

# %%
grid = [list(x.strip()) for x in data.split('\n')]

# %% [markdown]
# ## Part I

# %%
DijkstraGrid(grid, target='E', turn_cost=1000)
# Out:
# 7036
